# %%
from sdv.datasets.demo import get_available_demos

get_available_demos(modality='sequential')
# Out:
#                  dataset_name  size_MB  num_tables
# 0   ArticularyWordRecognition     7.95           1
# 1          AtrialFibrillation     0.77           1
# 2                BasicMotions     0.64           1
# 3       CharacterTrajectories    19.19           1
# 4                     Cricket    17.24           1
# 5               DuckDuckGeese   291.38           1
# 6                       ERing     1.25           1
# 7                  EchoNASDAQ     4.16           1
# 8                  EigenWorms   372.63           1
# 9                    Epilepsy     2.72           1
# 10       EthanolConcentration    51.38           1
# 11              FaceDetection   691.06           1
# 12            FingerMovements     5.32           1
# 13      HandMovementDirection    10.48           1
# 14                Handwriting     8.51           1
# 15                  Heartbeat    86.14           1
# 16             InsectWingbeat   547.59           1
# 17             JapaneseVowels     1.28           1
# 18                       LSST    14.18           1
# 19                     Libras     0.78           1
# 20               MotorImagery   616.90           1
# 21                     NATOPS     4.11           1
# 22                    PEMS-SF   490.15           1
# 23                  PenDigits     4.22           1
# 24             PhonemeSpectra   173.63           1
# 25               RacketSports     0.73           1
# 26         SelfRegulationSCP1    40.21           1
# 27         SelfRegulationSCP2    38.52           1
# 28         SpokenArabicDigits    47.63           1
# 29              StandWalkJump     4.32           1
# 30        UWaveGestureLibrary     7.76           1
# 31             nasdaq100_2019     1.65           1

# %%
from sdv.datasets.demo import download_demo

data, metadata = download_demo(
    modality='sequential',
    dataset_name='DuckDuckGeese',
    output_folder_name='sdv_demo_datasets/DuckDuckGeese/'
)
# Out:
# /Users/brigt/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/sdv/metadata/metadata.py:37: UserWarning: You are loading an older SingleTableMetadata object. This will be converted into the new Metadata object with a placeholder table name ('DuckDuckGeese'). Please save this new object for future usage.
#   warnings.warn(

# %%
metadata
# Out:
# {
#     "tables": {
#         "DuckDuckGeese": {
#             "columns": {
#                 "dim_478": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_848": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_163": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_638": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_115": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1246": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1339": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1289": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_258": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_706": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_687": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_468": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1249": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_809": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_425": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_774": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1267": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1248": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_37": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_347": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1017": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_277": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_374": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_523": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_114": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_316": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_506": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_568": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_496": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1295": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_641": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_895": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_13": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_28": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1341": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_90": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1326": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1214": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_157": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_304": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_738": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_49": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_797": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1238": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_59": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_484": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_334": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_761": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_772": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_231": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1160": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1232": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1302": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_676": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_722": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_850": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_187": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1101": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_673": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_158": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_566": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_255": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1136": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_953": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1261": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1306": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_766": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_392": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_933": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_96": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1164": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1316": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_996": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1211": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1110": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_318": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1085": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_150": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_655": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_68": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1083": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_289": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1224": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_616": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1177": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_666": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_750": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_177": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_47": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_799": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1016": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_378": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_545": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1082": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_401": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_934": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1014": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_212": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_463": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_779": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_31": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_511": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_583": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1287": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1062": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_362": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_460": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_669": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1175": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_60": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1066": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_505": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1180": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_329": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_414": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_130": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1197": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_790": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1068": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_299": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_820": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_188": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_213": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_251": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_609": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_668": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_951": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1025": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_195": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_310": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_764": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_134": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_237": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_813": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_841": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_936": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_534": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_185": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_253": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1036": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_216": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_333": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1132": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_492": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_167": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_732": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1158": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1111": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_170": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_291": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1095": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_156": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_528": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_714": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_408": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_373": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_263": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_840": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_1011": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_221": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_703": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_742": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_921": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_929": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_81": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_38": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_937": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_941": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim_93": {
#                     "sdtype": "numerical",
#                     "computer_representation": "Float"
#                 },
#                 "dim
# 4  0.000850  0.001005  0.000606  0.000983  ...   0.46779   0.58451   0.35527
#
#    dim_1338  dim_1339  dim_1340  dim_1341  dim_1342  dim_1343  dim_1344
# 0  0.072909   0.33849    1.5538   3.16440    4.2111    7.4078   14.6260
# 1  0.724850   0.89081    1.7591   2.83790    6.6453   11.3190   14.2550
# 2  0.265610   1.14800    1.6512   0.93226    3.3494    1.6533    6.4533
# 3  0.490880   0.89691    1.9294   2.92780    6.6976    8.1303    3.2575
# 4  0.728630   0.40299    1.1850   0.40135    8.9214   14.2250   11.2190
#
# [5 rows x 1349 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.relplot(data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 3
#       1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
# ----> 3 sns.relplot(data)
#
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/seaborn/relational.py:838, in relplot(data, x, y, hue, size, style, units, weights, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     829 g = FacetGrid(
#     830     data=full_data.dropna(axis=1, how="all"),
#     831     **grid_kws,
#    (...)    834     **facet_kws
#     835 )
#     837 # Draw the plot
# --> 838 g.map_dataframe(func, **plot_kws)
#     840 # Label the axes, using the original variables
#     841 # Pass "" when the variable name is None to overwrite internal variables
#     842 g.set_axis_labels(variables.get("x") or "", variables.get("y") or "")
#
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/seaborn/axisgrid.py:825, in FacetGrid.map_dataframe(self, func, *args, **kwargs)
#     822     kwargs["data"] = data_ijk
#     824     # Draw the plot
# --> 825     self._facet_plot(func, ax, args, kwargs)
#     827 # For axis labels, prefer to use positional args for backcompat
#     828 # but also extract the x/y kwargs and use if no corresponding arg
#     829 axis_labels = [kwargs.get("x", None), kwargs.get("y", None)]
#
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/seaborn/axisgrid.py:854, in FacetGrid._facet_plot(self, func, ax, plot_args, plot_kwargs)
#     852     plot_args = []
#     853     plot_kwargs["ax"] = ax
# --> 854 func(*plot_args, **plot_kwargs)
#     856 # Sort out the supporting information
#     857 self._update_legend_data(ax)
#
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/seaborn/relational.py:636, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     633 color = kwargs.pop("color", None)
#     634 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
# --> 636 p.plot(ax, kwargs)
#     638 return ax
#
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/seaborn/relational.py:449, in _ScatterPlotter.plot(self, ax, kws)
#     446     points.set_sizes(self._size_map(data["size"]))
#     448 if "style" in self.variables:
# --> 449     p = [self._style_map(val, "path") for val in data["style"]]
#     450     points.set_paths(p)
#     452 # Apply dependent default attributes
#
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/seaborn/relational.py:449, in <listcomp>(.0)
#     446     points.set_sizes(self._size_map(data["size"]))
#     448 if "style" in self.variables:
# --> 449     p = [self._style_map(val, "path") for val in data["style"]]
#     450     points.set_paths(p)
#     452 # Apply dependent default attributes
#
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/seaborn/_base.py:80, in SemanticMapping.__call__(self, key, *args, **kwargs)
#      77     """Apply the mapping to a single data value."""
#      78     return self.lookup_table[key]
# ---> 80 def __call__(self, key, *args, **kwargs):
#      81     """Get the attribute(s) values for the data key."""
#      82     if isinstance(key, (list, np.ndarray, pd.Series)):
#
# KeyboardInterrupt:
# Error in callback <function _draw_all_if_interactive at 0x16630d080> (for post_execute), with arguments args (),kwargs {}:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x103dbe4d0>>
# Traceback (most recent call last):
#   File "/Users/brigt/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/matplotlib/pyplot.py:279, in _draw_all_if_interactive()
#     277 def _draw_all_if_interactive() -> None:
#     278     if matplotlib.is_interactive():
# --> 279         draw_all()
#
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/matplotlib/_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/matplotlib/backend_bases.py:1891, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1889 if not self._is_idle_drawing:
#    1890     with self._idle_draw_cntx():
# -> 1891         self.draw(*args, **kwargs)
#
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     379 # Acquire a lock on the shared font cache.
#     380 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381       else nullcontext()):
# --> 382     self.figure.draw(self.renderer)
#     383     # A GUI class may be need to update a window using this draw, so
#     384     # don't forget to call the superclass.
#     385     super().draw()
#
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/matplotlib/artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/matplotlib/figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/matplotlib/axes/_base.py:3216, in _AxesBase.draw(self, renderer)
#    3213 if artists_rasterized:
#    3214     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3216 mimage._draw_list_compositing_images(
#    3217     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3219 renderer.close_group('axes')
#    3220 self.stale = False
#
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/matplotlib/collections.py:1008, in _CollectionWithSizes.draw(self, renderer)
#    1005 @artist.allow_rasterization
#    1006 def draw(self, renderer):
#    1007     self.set_sizes(self._sizes, self.get_figure(root=True).dpi)
# -> 1008     super().draw(renderer)
#
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/matplotlib/collections.py:430, in Collection.draw(self, renderer)
#     421         ipaths, ilinestyles = self._get_inverse_paths_linestyles()
#     422         renderer.draw_path_collection(
#     423             gc, transform.frozen(), ipaths,
#     424             self.get_transforms(), offsets, offset_trf,
#    (...)    427             self._antialiaseds, self._urls,
#     428             "screen")
# --> 430     renderer.draw_path_collection(
#     431         gc, transform.frozen(), paths,
#     432         self.get_transforms(), offsets, offset_trf,
#     433         self.get_facecolor(), self.get_edgecolor(),
#     434         self._linewidths, self._linestyles,
#     435         self._antialiaseds, self._urls,
#     436         "screen")  # offset_position, kept for backcompat.
#     438 gc.restore()
#     439 renderer.close_group(self.__class__.__name__)
#
# File ~/PycharmProjects/Syntehic_data/.venv/lib/python3.11/site-packages/matplotlib/path.py:211, in Path.vertices(self)
#     203     self._simplify_threshold = mpl.rcParams['path.simplify_threshold']
#     204     self._should_simplify = (
#     205         self._simplify_threshold > 0 and
#     206         mpl.rcParams['path.simplify'] and
#     207         len(self._vertices) >= 128 and
#     208         (self._codes is None or np.all(self._codes <= Path.LINETO))
#     209     )
# --> 211 @property
#     212 def vertices(self):
#     213     """The vertices of the `Path` as an (N, 2) array."""
#     214     return self._vertices
#
# KeyboardInterrupt:
